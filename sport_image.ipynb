# %%
import numpy as np
import cv2
import matplotlib
from matplotlib import pyplot as plt
# %matplotlib inline

# %%
img = cv2.imread('./test_images/Messi.jpg')
img.shape
# Out:
# (612, 408, 3)

# %%
plt.imshow(img)

# %%
gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
gray.shape
# Out:
# (612, 408)

# %%
plt.imshow(gray, cmap='gray')

# %%
face_cascade = cv2.CascadeClassifier('haarcascade_frontalface_default.xml')
eye_cascade = cv2.CascadeClassifier('haarcascade_eye.xml')

faces = face_cascade.detectMultiScale(gray,1.3,5)
faces
# Out:
# array([[103, 108, 211, 211]])

# %%
(x,y,w,h) = faces[0]
x,y,w,h
# Out:
# (103, 108, 211, 211)

# %%
face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
plt.imshow(face_img)

# %%
cv2.destroyAllWindows()
for (x,y,w,h) in faces:
    face_img = cv2.rectangle(img,(x,y),(x+w,y+h),(255,0,0),2)
    roi_gray = gray[y:y+h, x:x+w]
    roi_color = face_img[y:y+h, x:x+w]
    eyes = eye_cascade.detectMultiScale(roi_gray)
    for (ex,ey,ew,eh) in eyes:
        cv2.rectangle(roi_color,(ex,ey),(ex+ew,ey+eh),(0,255,0),2)
        

plt.figure()
plt.imshow(face_img, cmap='gray')
plt.show()

# %%
# %matplotlib inline
plt.imshow(roi_color, cmap='gray')

# %%
cropped_img = np.array(roi_color)
cropped_img.shape
# Out:
# (211, 211, 3)

# %%
import numpy as np
import pywt
import cv2    

def w2d(img, mode='haar', level=1):
    imArray = img
    #Datatype conversions
    #convert to grayscale
    imArray = cv2.cvtColor( imArray,cv2.COLOR_RGB2GRAY )
    #convert to float
    imArray =  np.float32(imArray)   
    imArray /= 255;
    # compute coefficients 
    coeffs=pywt.wavedec2(imArray, mode, level=level)

    #Process Coefficients
    coeffs_H=list(coeffs)  
    coeffs_H[0] *= 0;  

    # reconstruction
    imArray_H=pywt.waverec2(coeffs_H, mode);
    imArray_H *= 255;
    imArray_H =  np.uint8(imArray_H)
    return imArray_H

# %%
im_har = w2d(cropped_img,'db1',5)

# %%
def get_cropped_image_if_2_eyes(image_path):
    img = cv2.imread(image_path)
    gray = cv2.cvtColor(img, cv2.COLOR_BGR2GRAY)
    faces = face_cascade.detectMultiScale(gray, 1.5, 5)
    for (x,y,w,h) in faces:
        roi_gray = gray[y:y+h, x:x+w]
        roi_color = img[y:y+h, x:x+w]
        eyes = eye_cascade.detectMultiScale(roi_gray)
        if len(eyes) >= 2:
            return roi_color

# %%
original_image = cv2.imread('./test_images/Sharapova.jpg')
plt.imshow(original_image)

# %%
cropped_image = get_cropped_image_if_2_eyes('./test_images/Sharapova.jpg')
plt.imshow(cropped_image)

# %%
path_to_data = "./dataset/"
path_to_cr_data = "./dataset/cropped/"

# %%
import os
img_dirs = []
for entry in os.scandir(path_to_data):
    if entry.is_dir():
        img_dirs.append(entry.path)

# %%
img_dirs
# Out:
# ['./dataset/cropped',
#  './dataset/Maria',
#  './dataset/Messi',
#  './dataset/Roger',
#  './dataset/Serena',
#  './dataset/Virat']

# %%
import shutil
if os.path.exists(path_to_cr_data):
     shutil.rmtree(path_to_cr_data)
os.mkdir(path_to_cr_data)

# %%
cropped_image_dirs = []
celebrity_file_names_dict = {}
for img_dir in img_dirs:
    count = 1
    celebrity_name = img_dir.split('/')[-1]
    celebrity_file_names_dict[celebrity_name] = []
    for entry in os.scandir(img_dir):
        roi_color = get_cropped_image_if_2_eyes(entry.path)
        if roi_color is not None:
            cropped_folder = path_to_cr_data + celebrity_name
            if not os.path.exists(cropped_folder):
                os.makedirs(cropped_folder)
                cropped_image_dirs.append(cropped_folder)
                print("Generating cropped images in folder: ",cropped_folder)
            cropped_file_name = celebrity_name + str(count) + ".png"
            cropped_file_path = cropped_folder + "/" + cropped_file_name
            cv2.imwrite(cropped_file_path, roi_color)
            celebrity_file_names_dict[celebrity_name].append(cropped_file_path)
            count += 1
# Out:
# Generating cropped images in folder:  ./dataset/cropped/Maria
# Generating cropped images in folder:  ./dataset/cropped/Messi
# Generating cropped images in folder:  ./dataset/cropped/Roger
# Generating cropped images in folder:  ./dataset/cropped/Serena
# Generating cropped images in folder:  ./dataset/cropped/Virat

# %%
celebrity_file_names_dict = {}
for img_dir in cropped_image_dirs:
    celebrity_name = img_dir.split('/')[-1]
    file_list = []
    for entry in os.scandir(img_dir):
        file_list.append(entry.path)
    celebrity_file_names_dict[celebrity_name] = file_list
celebrity_file_names_dict
# Out:
# {'Maria': ['./dataset/cropped/Maria\\Maria1.png',
#   './dataset/cropped/Maria\\Maria10.png',
#   './dataset/cropped/Maria\\Maria11.png',
#   './dataset/cropped/Maria\\Maria12.png',
#   './dataset/cropped/Maria\\Maria13.png',
#   './dataset/cropped/Maria\\Maria14.png',
#   './dataset/cropped/Maria\\Maria15.png',
#   './dataset/cropped/Maria\\Maria16.png',
#   './dataset/cropped/Maria\\Maria17.png',
#   './dataset/cropped/Maria\\Maria18.png',
#   './dataset/cropped/Maria\\Maria19.png',
#   './dataset/cropped/Maria\\Maria2.png',
#   './dataset/cropped/Maria\\Maria20.png',
#   './dataset/cropped/Maria\\Maria21.png',
#   './dataset/cropped/Maria\\Maria22.png',
#   './dataset/cropped/Maria\\Maria23.png',
#   './dataset/cropped/Maria\\Maria24.png',
#   './dataset/cropped/Maria\\Maria25.png',
#   './dataset/cropped/Maria\\Maria26.png',
#   './dataset/cropped/Maria\\Maria27.png',
#   './dataset/cropped/Maria\\Maria28.png',
#   './dataset/cropped/Maria\\Maria29.png',
#   './dataset/cropped/Maria\\Maria3.png',
#   './dataset/cropped/Maria\\Maria30.png',
#   './dataset/cropped/Maria\\Maria4.png',
#   './dataset/cropped/Maria\\Maria5.png',
#   './dataset/cropped/Maria\\Maria6.png',
#   './dataset/cropped/Maria\\Maria7.png',
#   './dataset/cropped/Maria\\Maria8.png',
#   './dataset/cropped/Maria\\Maria9.png'],
#  'Messi': ['./dataset/cropped/Messi\\Messi1.png',
#   './dataset/cropped/Messi\\Messi10.png',
#   './dataset/cropped/Messi\\Messi11.png',
#   './dataset/cropped/Messi\\Messi12.png',
#   './dataset/cropped/Messi\\Messi13.png',
#   './dataset/cropped/Messi\\Messi14.png',
#   './dataset/cropped/Messi\\Messi15.png',
#   './dataset/cropped/Messi\\Messi16.png',
#   './dataset/cropped/Messi\\Messi17.png',
#   './dataset/cropped/Messi\\Messi18.png',
#   './dataset/cropped/Messi\\Messi19.png',
#   './dataset/cropped/Messi\\Messi2.png',
#   './dataset/cropped/Messi\\Messi20.png',
#   './dataset/cropped/Messi\\Messi21.png',
#   './dataset/cropped/Messi\\Messi22.png',
#   './dataset/cropped/Messi\\Messi23.png',
#   './dataset/cropped/Messi\\Messi24.png',
#   './dataset/cropped/Messi\\Messi25.png',
#   './dataset/cropped/Messi\\Messi26.png',
#   './dataset/cropped/Messi\\Messi27.png',
#   './dataset/cropped/Messi\\Messi28.png',
#   './dataset/cropped/Messi\\Messi29.png',
#   './dataset/cropped/Messi\\Messi3.png',
#   './dataset/cropped/Messi\\Messi30.png',
#   './dataset/cropped/Messi\\Messi31.png',
#   './dataset/cropped/Messi\\Messi32.png',
#   './dataset/cropped/Messi\\Messi33.png',
#   './dataset/cropped/Messi\\Messi34.png',
#   './dataset/cropped/Messi\\Messi35.png',
#   './dataset/cropped/Messi\\Messi36.png',
#   './dataset/cropped/Messi\\Messi37.png',
#   './dataset/cropped/Messi\\Messi38.png',
#   './dataset/cropped/Messi\\Messi4.png',
#   './dataset/cropped/Messi\\Messi5.png',
#   './dataset/cropped/Messi\\Messi6.png',
#   './dataset/cropped/Messi\\Messi7.png',
#   './dataset/cropped/Messi\\Messi8.png',
#   './dataset/cropped/Messi\\Messi9.png'],
#  'Roger': ['./dataset/cropped/Roger\\Roger1.png',
#   './dataset/cropped/Roger\\Roger10.png',
#   './dataset/cropped/Roger\\Roger11.png',
#   './dataset/cropped/Roger\\Roger12.png',
#   './dataset/cropped/Roger\\Roger13.png',
#   './dataset/cropped/Roger\\Roger14.png',
#   './dataset/cropped/Roger\\Roger15.png',
#   './dataset/cropped/Roger\\Roger16.png',
#   './dataset/cropped/Roger\\Roger17.png',
#   './dataset/cropped/Roger\\Roger18.png',
#   './dataset/cropped/Roger\\Roger19.png',
#   './dataset/cropped/Roger\\Roger2.png',
#   './dataset/cropped/Roger\\Roger20.png',
#   './dataset/cropped/Roger\\Roger21.png',
#   './dataset/cropped/Roger\\Roger22.png',
#   './dataset/cropped/Roger\\Roger23.png',
#   './dataset/cropped/Roger\\Roger24.png',
#   './dataset/cropped/Roger\\Roger25.png',
#   './dataset/cropped/Roger\\Roger26.png',
#   './dataset/cropped/Roger\\Roger27.png',
#   './dataset/cropped/Roger\\Roger3.png',
#   './dataset/cropped/Roger\\Roger4.png',
#   './dataset/cropped/Roger\\Roger5.png',
#   './dataset/cropped/Roger\\Roger6.png',
#   './dataset/cropped/Roger\\Roger7.png',
#   './dataset/cropped/Roger\\Roger8.png',
#   './dataset/cropped/Roger\\Roger9.png'],
#  'Serena': ['./dataset/cropped/Serena\\Serena1.png',
#   './dataset/cropped/Serena\\Serena10.png',
#   './dataset/cropped/Serena\\Serena11.png',
#   './dataset/cropped/Serena\\Serena12.png',
#   './dataset/cropped/Serena\\Serena13.png',
#   './dataset/cropped/Serena\\Serena14.png',
#   './dataset/cropped/Serena\\Serena15.png',
#   './dataset/cropped/Serena\\Serena16.png',
#   './dataset/cropped/Serena\\Serena17.png',
#   './dataset/cropped/Serena\\Serena18.png',
#   './dataset/cropped/Serena\\Serena19.png',
#   './dataset/cropped/Serena\\Serena2.png',
#   './dataset/cropped/Serena\\Serena20.png',
#   './dataset/cropped/Serena\\Serena21.png',
#   './dataset/cropped/Serena\\Serena22.png',
#   './dataset/cropped/Serena\\Serena23.png',
#   './dataset/cropped/Serena\\Serena24.png',
#   './dataset/cropped/Serena\\Serena25.png',
#   './dataset/cropped/Serena\\Serena26.png',
#   './dataset/cropped/Serena\\Serena27.png',
#   './dataset/cropped/Serena\\Serena28.png',
#   './dataset/cropped/Serena\\Serena29.png',
#   './dataset/cropped/Serena\\Serena3.png',
#   './dataset/cropped/Serena\\Serena30.png',
#   './dataset/cropped/Serena\\Serena31.png',
#   './dataset/cropped/Serena\\Serena32.png',
#   './dataset/cropped/Serena\\Serena33.png',
#   './dataset/cropped/Serena\\Serena34.png',
#   './dataset/cropped/Serena\\Serena35.png',
#   './dataset/cropped/Serena\\Serena36.png',
#   './dataset/cropped/Serena\\Serena4.png',
#   './dataset/cropped/Serena\\Serena5.png',
#   './dataset/cropped/Serena\\Serena6.png',
#   './dataset/cropped/Serena\\Serena7.png',
#   './dataset/cropped/Serena\\Serena8.png',
#   './dataset/cropped/Serena\\Serena9.png'],
#  'Virat': ['./dataset/cropped/Virat\\Virat1.png',
#   './dataset/cropped/Virat\\Virat10.png',
#   './dataset/cropped/Virat\\Virat11.png',
#   './dataset/cropped/Virat\\Virat12.png',
#   './dataset/cropped/Virat\\Virat13.png',
#   './dataset/cropped/Virat\\Virat14.png',
#   './dataset/cropped/Virat\\Virat15.png',
#   './dataset/cropped/Virat\\Virat16.png',
#   './dataset/cropped/Virat\\Virat17.png',
#   './dataset/cropped/Virat\\Virat18.png',
#   './dataset/cropped/Virat\\Virat19.png',
#   './dataset/cropped/Virat\\Virat2.png',
#   './dataset/cropped/Virat\\Virat20.png',
#   './dataset/cropped/Virat\\Virat21.png',
#   './dataset/cropped/Virat\\Virat22.png',
#   './dataset/cropped/Virat\\Virat23.png',
#   './dataset/cropped/Virat\\Virat24.png',
#   './dataset/cropped/Virat\\Virat25.png',
#   './dataset/cropped/Virat\\Virat26.png',
#   './dataset/cropped/Virat\\Virat27.png',
#   './dataset/cropped/Virat\\Virat28.png',
#   './dataset/cropped/Virat\\Virat29.png',
#   './dataset/cropped/Virat\\Virat3.png',
#   './dataset/cropped/Virat\\Virat30.png',
#   './dataset/cropped/Virat\\Virat31.png',
#   './dataset/cropped/Virat\\Virat32.png',
#   './dataset/cropped/Virat\\Virat33.png',
#   './dataset/cropped/Virat\\Virat34.png',
#   './dataset/cropped/Virat\\Virat4.png',
#   './dataset/cropped/Virat\\Virat5.png',
#   './dataset/cropped/Virat\\Virat6.png',
#   './dataset/cropped/Virat\\Virat7.png',
#   './dataset/cropped/Virat\\Virat8.png',
#   './dataset/cropped/Virat\\Virat9.png']}

# %%
class_dict = {}
count = 0
for celebrity_name in celebrity_file_names_dict.keys():
    class_dict[celebrity_name] = count
    count = count + 1
class_dict
# Out:
# {'Maria': 0, 'Messi': 1, 'Roger': 2, 'Serena': 3, 'Virat': 4}

# %%
X, y = [], []
for celebrity_name, training_files in celebrity_file_names_dict.items():
    for training_image in training_files:
        img = cv2.imread(training_image)
        scalled_raw_img = cv2.resize(img, (32, 32))
        img_har = w2d(img,'db1',5)
        scalled_img_har = cv2.resize(img_har, (32, 32))
        combined_img = np.vstack((scalled_raw_img.reshape(32*32*3,1),scalled_img_har.reshape(32*32,1)))
        X.append(combined_img)
        y.append(class_dict[celebrity_name])

# %%
X = np.array(X).reshape(len(X),4096).astype(float)
X.shape
# Out:
# (165, 4096)

# %%
from sklearn.svm import SVC
from sklearn.preprocessing import StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.pipeline import Pipeline
from sklearn.metrics import classification_report
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=0)

pipe = Pipeline([('scaler', StandardScaler()), ('svc', SVC(kernel = 'rbf', C = 10))])
pipe.fit(X_train, y_train)
pipe.score(X_test, y_test)
# Out:
# 0.7142857142857143

# %%
  from sklearn import svm
from sklearn.ensemble import RandomForestClassifier
from sklearn.linear_model import LogisticRegression
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import GridSearchCV
model_params = {
    'svm': {
        'model': svm.SVC(gamma='auto',probability=True),
        'params' : {
    'svc__C': [1,10,100,1000],
            'svc__kernel': ['rbf','linear']
    }  
    },
    'random_forest': {
        'model': RandomForestClassifier(),
        'params' : {
            'randomforestclassifier__n_estimators': [1,5,10]
        }
    },
    'logistic_regression' : {
        'model': LogisticRegression(solver='liblinear',multi_class='auto'),
        'params': {
            'logisticregression__C': [1,5,10]
        }
    }
}
scores = []
best_estimators = {}
import pandas as pd
for algo, mp in model_params.items():
    pipe = make_pipeline(StandardScaler(), mp['model'])
    clf =  GridSearchCV(pipe, mp['params'], cv=5, return_train_score=False)
    clf.fit(X_train, y_train)
    scores.append({
        'model': algo,
        'best_score': clf.best_score_,
        'best_params': clf.best_params_
    })
    best_estimators[algo] = clf.best_estimator_
    
df = pd.DataFrame(scores,columns=['model','best_score','best_params'])
df
# Out:
#                  model  best_score  \
# 0                  svm    0.658000
# 1        random_forest    0.463667
# 2  logistic_regression    0.691000
#
#                                     best_params
# 0        {'svc__C': 1, 'svc__kernel': 'linear'}
# 1  {'randomforestclassifier__n_estimators': 10}
# 2                  {'logisticregression__C': 1}

# %%
best_estimators['svm'].score(X_test,y_test)
# Out:
# 0.6904761904761905

# %%
best_clf = best_estimators['svm']
from sklearn.metrics import confusion_matrix
cm = confusion_matrix(y_test, best_clf.predict(X_test))
cm
# Out:
# array([[ 6,  0,  1,  0,  0],
#        [ 0, 10,  0,  0,  2],
#        [ 0,  3,  3,  0,  0],
#        [ 0,  1,  0,  5,  1],
#        [ 0,  3,  1,  1,  5]], dtype=int64)

# %%
import seaborn as sn
plt.figure(figsize = (10,7))
sn.heatmap(cm, annot=True)
plt.xlabel('Predicted')
plt.ylabel('Truth')
# Out:
# Text(69.0, 0.5, 'Truth')

# %%
class_dict
# Out:
# {'Maria': 0, 'Messi': 1, 'Roger': 2, 'Serena': 3, 'Virat': 4}

# %%
# !pip install joblib
import joblib 
# Save the model as a pickle in a file 
joblib.dump(best_clf, 'saved_model.pkl')
# Out:
# Requirement already satisfied: joblib in c:\users\sambuddha pal\anaconda3\lib\site-packages (1.2.0)
# ['saved_model.pkl']

# %%
import json
with open("class_dictionary.json","w") as f:
    f.write(json.dumps(class_dict))
